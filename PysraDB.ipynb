# %%
from pysradb import SRAweb
from pysradb.search import GeoSearch
# Out:
# C:\Users\Lordleojz\.conda\envs\pysradb\lib\site-packages\pysradb\utils.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
db = SRAweb()

# %%
instance = GeoSearch(accession='GSE201016')
instance.search()
df = instance.get_df()
# Out:
# No results found for the following search query:
#  {'query': 'sra gds[Filter]', 'accession': 'GSE201016', 'organism': None, 'layout': None, 'mbases': None, 'publication_date': None, 'platform': None, 'selection': None, 'source': None, 'strategy': None, 'title': None}

# %%
df
# Out:
#    study_accession experiment_accession  \
# 0        SRP270837           SRX8684079
# 1        SRP260279           SRX8727223
# 2        SRP334053          SRX11904692
# 3        SRP265007           SRX8409270
# 4        SRP334335          SRX11931944
# 5        SRP334335          SRX11931948
# 6        SRP334335          SRX11931946
# 7        SRP352130          SRX13486793
# 8        SRP334335          SRX11931957
# 9        SRP282598           SRX9134591
# 10       SRP334335          SRX11931959
# 11       SRP352130          SRX13486792
# 12       SRP347078          SRX13182673
# 13       SRP295569           SRX9621736
# 14       SRP334053          SRX11904688
# 15       SRP334335          SRX11931953
# 16       SRP347078          SRX13182674
# 17       SRP295569           SRX9621732
# 18       SRP295569           SRX9621741
# 19       SRP295569           SRX9621745
#
#                                      experiment_title sample_taxon_id  \
# ...

# %%
data =df.at[0,"run_1_accession"]
data
# Out:
# 'SRR12169246'

# %%
from Bio import Entrez
Entrez.email = "leonardo.juarez2858@alumnos.udg.mx"
handle = Entrez.esearch(db="gds", term="SARS-COV-2", retmax=10)
info = handle.read()
handle.close()
info
# Out:
# b'<?xml version="1.0" encoding="UTF-8" ?>\n<!DOCTYPE eSearchResult PUBLIC "-//NLM//DTD esearch 20060628//EN" "https://eutils.ncbi.nlm.nih.gov/eutils/dtd/20060628/esearch.dtd">\n<eSearchResult><Count>10994</Count><RetMax>10</RetMax><RetStart>0</RetStart><IdList>\n<Id>200207077</Id>\n<Id>200203030</Id>\n<Id>200174382</Id>\n<Id>200189731</Id>\n<Id>200206996</Id>\n<Id>200193879</Id>\n<Id>200206455</Id>\n<Id>200189514</Id>\n<Id>200178699</Id>\n<Id>200174621</Id>\n</IdList><TranslationSet><Translation>     <From>SARS-COV-2</From>     <To>"Severe acute respiratory syndrome coronavirus 2"[Organism] OR SARS-COV-2[All Fields]</To>    </Translation></TranslationSet><TranslationStack>   <TermSet>    <Term>"Severe acute respiratory syndrome coronavirus 2"[Organism]</Term>    <Field>Organism</Field>    <Count>1096</Count>    <Explode>Y</Explode>   </TermSet>   <TermSet>    <Term>SARS-COV-2[All Fields]</Term>    <Field>All Fields</Field>    <Count>10859</Count>    <Explode>N</Explode>   </TermSet> 
# ...

# %%
instance.show_result_statistics()

# %%
instance.visualise_results()

# %%
df = db.sra_metadata(['GSM5949694'])
df
