# %%
from pysradb.search import GeoSearch

# %%
$ wget -c https://download.asperasoft.com/download/sw/connect/3.9.9/ibm-aspera-connect-3.9.9.177872-linux-g2.12-64.tar.gz
$ tar -zxvf ibm-aspera-connect-3.9.9.177872-linux-g2.12-64.tar.gz && ls
$ bash ibm-aspera-connect-3.9.9.177872-linux-g2.12-64.sh

# %%
# !wget -P D:/Documentos/CUCEI/Lab https://download.asperasoft.com/download/sw/connect/3.9.9/ibm-aspera-connect-3.9.9.177872-linux-g2.12-64.tar.gz
# Out:
# --2022-07-11 13:18:49--  https://download.asperasoft.com/download/sw/connect/3.9.9/ibm-aspera-connect-3.9.9.177872-linux-g2.12-64.tar.gz
# Resolving download.asperasoft.com (download.asperasoft.com)... 184.72.56.59
# Connecting to download.asperasoft.com (download.asperasoft.com)|184.72.56.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37797375 (36M) [application/x-gzip]
# Saving to: 'D:/Documentos/CUCEI/Lab/ibm-aspera-connect-3.9.9.177872-linux-g2.12-64.tar.gz'
#
#      0K .......... .......... .......... .......... ..........  0% 2.23M 16s
#     50K .......... .......... .......... .......... ..........  0%  765K 32s
#    100K .......... .......... .......... .......... ..........  0% 6.43M 23s
#    150K .......... .......... .......... .......... ..........  0% 18.1M 18s
#    200K .......... .......... .......... .......... ..........  0%  774K 24s
#    250K .......... .......... .......... .......... ..........  0% 17.9M 20s
# ...

# %%
# %%bash
# ./Lab/ibm-aspera-connect-3.9.9.177872-linux-g2.12-64/ibm-aspera-connect-3.9.9.177872-linux-g2.12-64.sh
# Out:
# Installing IBM Aspera Connect
#
# Deploying IBM Aspera Connect (/home/lordleojz/.aspera/connect) for the current user only.
# Unable to register protocol handler, IBM Aspera Connect won't be able to auto-launch
# Unable to update desktop database, IBM Aspera Connect may not be able to auto-launch
#
# Install complete.

# %% [markdown]
# Con esto configurado ya podemos hacer descargas mas rapidas

# %% [markdown]
# Descomprimir el archivo usando TAR

# %%
instance = GeoSearch(verbosity=3,query="")
instance.search()
instance.get_df()
# Out:
# 100%|██████████| 20/20 [00:01<00:00, 15.44it/s]
#    study_accession experiment_accession  \
# 0        SRP379160          SRX15633797
# 1        SRP379160          SRX15633796
# 2        SRP379160          SRX15633795
# 3        SRP379160          SRX15633794
# 4        SRP379160          SRX15633793
# 5        SRP379160          SRX15633792
# 6        SRP379160          SRX15633791
# 7        SRP379160          SRX15633790
# 8        SRP379160          SRX15633789
# 9        SRP379160          SRX15633788
# 10       SRP379160          SRX15633787
# 11       SRP379160          SRX15633786
# 12       SRP379160          SRX15633785
# 13       SRP379160          SRX15633784
# 14       SRP379160          SRX15633783
# 15       SRP379160          SRX15633782
# 16       SRP379160          SRX15633781
# 17       SRP379160          SRX15633780
# 18       SRP379160          SRX15633779
# 19       SRP379160          SRX15633778
#
# ...

# %%
from pysradb.sraweb import SRAweb
db = SRAweb()
metadata = db.sra_metadata("GSE189431",detailed=True)
metadata
# Out:
# No results found for GSE189431
